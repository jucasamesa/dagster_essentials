# %%
import os
import duckdb

# %%
with duckdb.connect("../../../../data/staging/data.duckdb") as conn:
    result = conn.execute("select count(*) from trips").fetchall()

result
# Out:
# [(3403766,)]

# %%
with duckdb.connect("../../../../data/staging/data.duckdb") as conn:
    result = conn.execute("select count(*) from zones").fetchall()
result
# Out:
# [(263,)]

# %%
conn.close()
